# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer  # Changed import to use Keras from TensorFlow
from tensorflow.keras.preprocessing.sequence import pad_sequences  # Corrected import for pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
#read dataset
with open('urdu dataset_.txt','r',encoding='utf-8') as file:
    text=file.read()

# %%
#Tokenizer process
tokenizer=Tokenizer()
#fit
tokenizer.fit_on_texts([text])
#assign length of word index
total_words=len(tokenizer.word_index)+1

# %%
tokenizer.word_index
# Out:
# {'طالب': 1,
#  'علم': 2,
#  'یونیورسٹی': 3,
#  'کے': 4,
#  'میں': 5,
#  'کی': 6,
#  'ہے۔': 7,
#  '1': 8,
#  'نئے': 9,
#  'لیے': 10,
#  'کیا': 11,
#  '2': 12,
#  'فیکلٹی': 13,
#  'نے': 14,
#  'ہیں۔': 15,
#  'اور': 16,
#  'بہت': 17,
#  'سے': 18,
#  'کا': 19,
#  'طلبہ': 20,
#  '4': 21,
#  'بھی': 22,
#  '3': 23,
#  'ہو': 24,
#  'پر': 25,
#  'ہم': 26,
#  'پروگرامز': 27,
#  'کو': 28,
#  'عالمی': 29,
#  'ہے؟': 30,
#  'ہاں،': 31,
#  'شروع': 32,
#  'ہے': 33,
#  'مختلف': 34,
#  'تعلیم': 35,
#  'معیار': 36,
#  'رہے': 37,
#  'ہمارے': 38,
#  'سطح': 39,
#  'رہا': 40,
#  'تعلیمی': 41,
#  'کیے': 42,
#  'کر': 43,
#  'جا': 44,
#  'اس': 45,
#  'نیا': 46,
#  'ہے،': 47,
#  'تاکہ': 48,
#  'تحقیق': 49,
#  'مواقع': 50,
#  'متعارف': 51,
#  'کرنے': 52,
#  'بہتر': 53,
#  'نئی': 54,
#  'بہترین': 55,
#  'فائدہ': 56,
#  'زیادہ': 57,
#  'جی': 58,
#  'فراہم': 59,
#  'ہیں': 60,
#  'رہی': 61,
#  'ہمیں': 62,
#  'ہیں،': 63,
#  'بارے': 64,
#  'کورسز': 65,
#  'ہوئے': 66,
#  'طور': 67,
#  'ٹی': 68,
#  'حال': 69,
#  'تحقیقاتی': 70,
#  'بین': 71,
#  'الاقوامی': 72,
#  'اب': 73,
#  'جس': 74,
#  'سب': 75,
#  'سی': 76,
#  'جو': 77,
#  'وہ': 78,
#  'جاتا': 79,
#  'آپ': 80,
#  'جدید': 81,
#  'ہیں؟': 82,
#  'کھیلوں': 83,
#  'بن': 84,
#  'کہ': 85,
#  'اپنی': 86,
#  'یہ': 87,
#  'ہمیشہ': 88,
#  'گئے': 89,
#  'کرائے': 90,
#  'ثابت': 91,
#  'سال': 92,
#  'خاص': 93,
#  'آئی': 94,
#  'ہی': 95,
#  'اپنے': 96,
#  'آن': 97,
#  'لائن': 98,
#  'دستیاب': 99,
#  'کیمپس': 100,
#  'سنا؟': 101,
#  'سکیں۔': 102,
#  'سیمینارز': 103,
#  'ہاسٹل': 104,
#  'کچھ': 105,
#  'اہتمام': 106,
#  'ہونے': 107,
#  'ہوں': 108,
#  'مکمل': 109,
#  'فخر': 110,
#  'والے': 111,
#  'سہولت': 112,
#  'کیریئر': 113,
#  'ٹیکنالوجیز': 114,
#  'استعمال': 115,
#  'کرتے': 116,
#  'شعبوں': 117,
#  'کام': 118,
#  'یونیورسٹیز': 119,
#  'پرانے': 120,
#  'رہنمائی': 121,
#  'ضرورت': 122,
#  'اقدامات': 123,
#  'تدریسی': 124,
#  'پروگرام': 125,
#  'چکا': 126,
#  'اشتراک': 127,
#  'مل': 128,
#  'سکے۔': 129,
#  'کمیونٹی': 130,
#  'آفس': 131,
#  'معلومات': 132,
#  'بڑھانے': 133,
#  'مند': 134,
#  'حاصل': 135,
#  'سسٹم': 136,
#  'تم': 137,
#  'آف': 138,
#  'سندھ': 139,
#  'سنا': 140,
#  'بیالوجی': 141,
#  'میں۔': 142,
#  'منصوبوں': 143,
#  'پیش': 144,
#  'کیا۔': 145,
#  'لائبریری': 146,
#  'وہاں': 147,
#  'مواد': 148,
#  'جریدے': 149,
#  'کمپیوٹر': 150,
#  'لیب': 151,
#  'بنا': 152,
#  'ویسے،': 153,
#  'پسندیدہ': 154,
#  'جگہ': 155,
#  'کون': 156,
#  'میرے': 157,
#  'خیال': 158,
#  'بیچ': 159,
#  'سبزہ': 160,
#  'زار': 161,
#  'خوبصورت': 162,
#  'ہر': 163,
#  'ورکشاپس': 164,
#  'انعقاد': 165,
#  'پالیسی': 166,
#  'انہوں': 167,
#  'مزید': 168,
#  'تحقیقی': 169,
#  'فنڈز': 170,
#  'کانفرنسز': 171,
#  'منصوبہ': 172,
#  'بندی': 173,
#  'حالت': 174,
#  'کیسی': 175,
#  'آرام': 176,
#  'دہ': 177,
#  'سہولتوں': 178,
#  'آراستہ': 179,
#  'کلچر': 180,
#  'ثقافتی': 181,
#  'تقریبات': 182,
#  'فیسٹیولز': 183,
#  'والی': 184,
#  'سرگرمیاں': 185,
#  'کب': 186,
#  'گی؟': 187,
#  'اسٹیڈیم': 188,
#  'تیاری': 189,
#  'تقریباً': 190,
#  'چکی': 191,
#  'قائم': 192,
#  'خواتین': 193,
#  'اچھا': 194,
#  'فیلڈز': 195,
#  'بڑھتی': 196,
#  'ہوئی': 197,
#  'ضروری': 198,
#  'سپورٹس': 199,
#  'ٹیم': 200,
#  'ٹیموں': 201,
#  'کرایا': 202,
#  'ایونٹس': 203,
#  'لائیو': 204,
#  'اسٹریمنگ': 205,
#  'گے۔': 206,
#  'مجھے': 207,
#  'یقین': 208,
#  'علموں': 209,
#  'ترقی': 210,
#  'اضافہ': 211,
#  'ہوگا۔': 212,
#  'ہو۔': 213,
#  'تعداد': 214,
#  'دونوں': 215,
#  'کہتے': 216,
#  'پروفیسرز': 217,
#  'انتخاب': 218,
#  'ترغیب': 219,
#  'دی': 220,
#  'کوئی': 221,
#  'ایڈوکیشنل': 222,
#  'ٹورز': 223,
#  'دورے': 224,
#  'باقاعدہ': 225,
#  'ایک': 226,
#  'قیمتی': 227,
#  'اثاثہ': 228,
#  'ان': 229,
#  'ہوتی': 230,
#  'داخلہ': 231,
#  'لینے': 232,
#  'داخلے': 233,
#  'جامع': 234,
#  'کروائے': 235,
#  'تدریس': 236,
#  'طریقے': 237,
#  'اپنائے': 238,
#  'جانب': 239,
#  'موضوعات': 240,
#  'تلاش': 241,
#  'ریسرچ': 242,
#  'پارٹنرشپ': 243,
#  'اہمیت': 244,
#  'اختیار': 245,
#  'نصاب': 246,
#  'بنانے': 247,
#  'اداروں': 248,
#  'وقت': 249,
#  'طریقوں': 250,
#  'شامل': 251,
#  'سروس': 252,
#  'کامیاب': 253,
#  'ایڈمنسٹریٹو': 254,
#  'کھولا': 255,
#  'ذریعے': 256,
#  'مسائل': 257,
#  'درخواستوں': 258,
#  'حل': 259,
#  'آپشنز': 260,
#  'حوالے': 261,
#  'دینے': 262,
#  'منعقد': 263,
#  'لیبز': 264,
#  'تھی،': 265,
#  'گئی': 266,
#  'دنیا': 267,
#  'بھر': 268,
#  'منصوبے': 269,
#  'اسپیشلائزڈ': 270,
#  'مجھ': 271,
#  'تمہاری': 272,
#  'باتوں': 273,
#  'جواب': 274,
#  'ملا،': 275,
#  'شکریہ': 276,
#  'ماحول': 277,
#  'ادارے': 278,
#  'بہتری': 279,
#  'آ': 280,
#  'حصہ': 281,
#  'محسوس': 282,
#  'ہماری': 283,
#  'بڑی': 284,
#  'کامیابی': 285,
#  'یہی': 286,
#  'گیا': 287,
#  'رفتار': 288,
#  'تیز': 289,
#  'مددگار': 290,
#  'موقع': 291,
#  'دیتے': 292,
#  'ہمارا': 293,
#  'مقصد': 294,
#  'دینا': 295,
#  'پیشہ': 296,
#  'ور': 297,
#  'ویب': 298,
#  'سائٹ': 299,
#  'تمام': 300,
#  'آسانی': 301,
#  'مدد': 302,
#  'ملتی': 303,
#  'یونیورس': 304,
#  'موجود': 305,
#  'سینٹر': 306,
#  'مفید': 307,
#  'فلاح': 308,
#  'جن': 309,
#  'اٹھا': 310,
#  'سکتے': 311,
#  'پذیرائی': 312,
#  'متعدد': 313,
#  'ساتھ': 314}

# %%
len(tokenizer.word_index)
# Out:
# 314

# %%
#n-gram model
#declare n-grams
input_sequences=[]
#splitting from \n
for line in text.split('\n'):
    #getting tokens
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1,len(token_list)):
       n_gram_sequence = token_list[:i+1]
       input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 11],
#  [1, 2, 8, 11, 137],
#  [1, 2, 8, 11, 137, 14],
#  [1, 2, 8, 11, 137, 14, 3],
#  [1, 2, 8, 11, 137, 14, 3, 138],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4, 9],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4, 9, 27],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4, 9, 27, 4],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4, 9, 27, 4, 64],
#  [1, 2, 8, 11, 137, 14, 3, 138, 139, 4, 9, 27, 4, 64, 5],
#  [1, 2, 23, 11, 80, 14, 3, 6, 54, 70, 166, 4, 64],
#  [1, 2, 23, 11, 80, 14, 3, 6, 54, 70, 166, 4, 64, 5],
#  [1, 2, 23, 11, 80, 14, 3, 6, 54, 70, 166, 4, 64, 5, 101],
#  [1, 2],
#  [1, 2, 12],
#  [1, 2, 12, 58],
#  [1, 2, 12, 58, 31],
#  [1, 2, 12, 58, 31, 167],
#  [1, 2, 12, 58, 31, 167, 14],
#  [1, 2, 12, 58, 31, 167, 14, 168],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60, 48],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60, 48, 26],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60, 48, 26, 29],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60, 48, 26, 29, 39],
#  [1, 2, 12, 58, 31, 167, 14, 168, 169, 170, 59, 42, 60, 48, 26, 29, 39, 25],
#  [1,
#   2,
#   12,
#   58,
#   31,
#   167,
#   14,
#   168,
#   169,
#   170,
#   59,
#   42,
#   60,
#   48,
#   26,
#   29,
#   39,
#   25,
#   49],
#  [1,
#   2,
#   12,
#   58,
#   31,
#   167,
#   14,
#   168,
#   169,
#   170,
#   59,
#   42,
#   60,
#   48,
#   26,
#   29,
#   39,
#   25,
#   49,
#   43],
#  [1,
#   2,
#   12,
#   58,
#   31,
#   167,
#   14,
#   168,
#   169,
#   170,
#   59,
#   42,
#   60,
#   48,
#   26,
#   29,
#   39,
#   25,
#   49,
#   43,
#   102],
#  [13, 12],
#  [13, 12, 26],
#  [13, 12, 26, 14],
#  [13, 12, 26, 14, 9],
#  [13, 12, 26, 14, 9, 41],
#  [13, 12, 26, 14, 9, 41, 103],
#  [13, 12, 26, 14, 9, 41, 103, 16],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6, 22],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6, 22, 172],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6, 22, 172, 173],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6, 22, 172, 173, 6],
#  [13, 12, 26, 14, 9, 41, 103, 16, 171, 6, 22, 172, 173, 6, 7],
#  [1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 3],
#  [1, 2, 8, 3, 4],
#  [1, 2, 8, 3, 4, 9],
#  [1, 2, 8, 3, 4, 9, 104],
#  [1, 2, 8, 3, 4, 9, 104, 6],
#  [1, 2, 21, 11, 3, 5, 221, 93, 222, 223, 19, 106, 11, 44, 40, 30],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 58],
#  [1, 2, 23, 58, 31],
#  [1, 2, 23, 58, 31, 34],
#  [1, 2, 23, 58, 31, 34, 119],
#  [1, 2, 23, 58, 31, 34, 119, 4],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225, 67],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225, 67, 25],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225, 67, 25, 24],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225, 67, 25, 24, 37],
#  [1, 2, 23, 58, 31, 34, 119, 4, 41, 224, 22, 225, 67, 25, 24, 37, 15],
#  [1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 3],
#  [1, 2, 8, 3, 4],
#  [1, 2, 8, 3, 4, 120],
#  [1, 2, 8, 3, 4, 120, 20],
#  [1, 2, 8, 3, 4, 120, 20, 19],
#  [1, 2, 8, 3, 4, 120, 20, 19, 11],
#  [1, 2, 8, 3, 4, 120, 20, 19, 11, 69],
#  [1, 2, 8, 3, 4, 120, 20, 19, 11, 69, 30],
#  [13, 12],
#  [13, 12, 3],
#  [13, 12, 3, 4],
#  [13, 12, 3, 4, 120],
#  [13, 12, 3, 4, 120, 20],
#  [13, 12, 3, 4, 120, 20, 38],
#  [13, 12, 3, 4, 120, 20, 38, 10],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16, 62],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16, 62, 229],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16, 62, 229, 6],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16, 62, 229, 6, 121],
#  [13, 12, 3, 4, 120, 20, 38, 10, 226, 227, 228, 60, 16, 62, 229, 6, 121, 6],
#  [13,
#   12,
#   3,
#   4,
#   120,
#   20,
#   38,
#   10,
#   226,
#   227,
#   228,
#   60,
#   16,
#   62,
#   229,
#   6,
#   121,
#   6,
#   122],
#  [13,
#   12,
#   3,
#   4,
#   120,
#   20,
#   38,
#   10,
#   226,
#   227,
#   228,
#   60,
#   16,
#   62,
#   229,
#   6,
#   121,
#   6,
#   122,
#   230],
#  [13,
#   12,
#   3,
#   4,
#   120,
#   20,
#   38,
#   10,
#   226,
#   227,
#   228,
#   60,
#   16,
#   62,
#   229,
#   6,
#   121,
#   6,
#   122,
#   230,
#   7],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 3],
#  [1, 2, 21, 3, 5],
#  [1, 2, 21, 3, 5, 9],
#  [1, 2, 21, 3, 5, 9, 231],
#  [1, 2, 21, 3, 5, 9, 231, 232],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10, 11],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10, 11, 123],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10, 11, 123, 42],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10, 11, 123, 42, 89],
#  [1, 2, 21, 3, 5, 9, 231, 232, 111, 20, 4, 10, 11, 123, 42, 89, 82],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 3],
#  [1, 2, 23, 3, 14],
#  [1, 2, 23, 3, 14, 9],
#  [1, 2, 23, 3, 14, 9, 233],
#  [1, 2, 23, 3, 14, 9, 233, 4],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10, 34],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10, 34, 16],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10, 34, 16, 57],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10, 34, 16, 57, 234],
#  [1, 2, 23, 3, 14, 9, 233, 4, 10, 16, 20, 6, 121, 4, 10, 34, 16, 57, 234, 27],
#  [1,
#   2,
#   23,
#   3,
#   14,
#   9,
#   233,
#   4,
#   10,
#   16,
#   20,
#   6,
#   121,
#   4,
#   10,
#   34,
#   16,
#   57,
#   234,
#   27,
#   51],
#  [1,
#   2,
#   23,
#   3,
#   14,
#   9,
#   233,
#   4,
#   10,
#   16,
#   20,
#   6,
#   121,
#   4,
#   10,
#  [1, 2, 8, 3, 19, 242, 243, 125, 17, 244, 245],
#  [1, 2, 8, 3, 19, 242, 243, 125, 17, 244, 245, 43],
#  [1, 2, 8, 3, 19, 242, 243, 125, 17, 244, 245, 43, 126],
#  [1, 2, 8, 3, 19, 242, 243, 125, 17, 244, 245, 43, 126, 7],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 3],
#  [1, 2, 21, 3, 14],
#  [1, 2, 21, 3, 14, 246],
#  [1, 2, 21, 3, 14, 246, 4],
#  [1, 2, 21, 3, 14, 246, 4, 36],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29, 41],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29, 41, 248],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29, 41, 248, 18],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29, 41, 248, 18, 127],
#  [1, 2, 21, 3, 14, 246, 4, 36, 28, 53, 247, 4, 10, 29, 41, 248, 18, 127, 11],
#  [1,
#   2,
#   21,
#   3,
#   14,
#   246,
#   4,
#   36,
#   28,
#   53,
#   247,
#   4,
#   10,
#   29,
#   41,
#   248,
#   18,
#   127,
#   11,
#   7],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 45],
#  [1, 2, 23, 45, 249],
#  [1, 2, 23, 45, 249, 3],
#  [1, 2, 23, 45, 249, 3, 5],
#  [1, 2, 23, 45, 249, 3, 5, 17],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114, 19],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114, 19, 115],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114, 19, 115, 24],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114, 19, 115, 24, 40],
#  [1, 2, 23, 45, 249, 3, 5, 17, 76, 54, 114, 19, 115, 24, 40, 7],
#  [13, 12],
#  [13, 12, 26],
#  [13, 12, 26, 3],
#  [13, 12, 26, 3, 5],
#  [13, 12, 26, 3, 5, 81],
#  [13, 12, 26, 3, 5, 81, 124],
#  [13, 12, 26, 3, 5, 81, 124, 250],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60, 48],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60, 48, 20],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60, 48, 20, 28],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60, 48, 20, 28, 55],
#  [13, 12, 26, 3, 5, 81, 124, 250, 28, 251, 43, 37, 60, 48, 20, 28, 55, 35],
#  [13,
#   12,
#   26,
#   3,
#   5,
#   81,
#   124,
#   250,
#   28,
#   251,
#   43,
#   37,
#   60,
#   48,
#   20,
#   28,
#   55,
#   35,
#   128],
#  [13,
#   12,
#   26,
#   3,
#   5,
#   81,
#   124,
#   250,
#   28,
#   251,
#   43,
#   37,
#   60,
#   48,
#   20,
#   28,
#   55,
#   35,
#   128,
#   129],
#  [1, 2],
#  [1, 2, 12],
#  [1, 2, 12, 3],
#  [1, 2, 12, 3, 6],
#  [1, 2, 12, 3, 6, 130],
#  [1, 2, 12, 3, 6, 130, 252],
#  [1, 2, 12, 3, 6, 130, 252, 27],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22, 17],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22, 17, 253],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22, 17, 253, 24],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22, 17, 253, 24, 37],
#  [1, 2, 12, 3, 6, 130, 252, 27, 22, 17, 253, 24, 37, 15],
#  [1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 11],
#  [1, 2, 8, 11, 3],
#  [1, 2, 8, 11, 3, 14],
#  [1, 2, 8, 11, 3, 14, 46],
#  [1, 2, 8, 11, 3, 14, 46, 254],
#  [1, 2, 8, 11, 3, 14, 46, 254, 131],
#  [1, 2, 8, 11, 3, 14, 46, 254, 131, 255],
#  [1, 2, 8, 11, 3, 14, 46, 254, 131, 255, 30],
#  [13, 8],
#  [13, 8, 58],
#  [13, 8, 58, 31],
#  [13, 8, 58, 31, 45],
#  [13, 8, 58, 31, 45, 9],
#  [13, 8, 58, 31, 45, 9, 131],
#  [13, 8, 58, 31, 45, 9, 131, 4],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258, 19],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258, 19, 53],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258, 19, 53, 67],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258, 19, 53, 67, 25],
#  [13, 8, 58, 31, 45, 9, 131, 4, 256, 20, 4, 257, 16, 258, 19, 53, 67, 25, 259],
#  [13,
#   8,
#   58,
#   31,
#   45,
#   9,
#   131,
#   4,
#   256,
#   20,
#   4,
#   257,
#   16,
#   258,
#   19,
#   53,
#   67,
#   25,
#   259,
#   11],
#  [13,
#   8,
#   58,
#   31,
#   45,
#   9,
#   131,
#   4,
#   256,
#   20,
#   4,
#   257,
#   16,
#   258,
#   19,
#   53,
#   67,
#   25,
#   259,
#   11,
#   44],
#  [13,
#   8,
#   58,
#   31,
#   45,
#   9,
#   131,
#   4,
#   256,
#   20,
#   4,
#   257,
#   16,
#   258,
#   19,
#   53,
#   67,
#   25,
#   259,
#   11,
#   44,
#   40],
#  [13,
#   8,
#   58,
#   31,
#   45,
#   9,
#   131,
#   4,
#   256,
#   20,
#   4,
#   257,
#   16,
#   258,
#   19,
#   53,
#   67,
#   25,
#   259,
#   11,
#   44,
#   40,
#   7],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 3],
#  [1, 2, 23, 3, 4],
#  [1, 2, 23, 3, 4, 34],
#  [1, 2, 23, 3, 4, 34, 117],
#  [1, 2, 23, 3, 4, 34, 117, 5],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260, 22],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260, 22, 51],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260, 22, 51, 90],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260, 22, 51, 90, 89],
#  [1, 2, 23, 3, 4, 34, 117, 5, 9, 113, 260, 22, 51, 90, 89, 15],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 3],
#  [1, 2, 21, 3, 5],
#  [1, 2, 21, 3, 5, 9],
#  [1, 2, 21, 3, 5, 9, 41],
#  [1, 2, 21, 3, 5, 9, 41, 27],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4, 10],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4, 10, 103],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4, 10, 103, 22],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4, 10, 103, 22, 263],
#  [1, 2, 21, 3, 5, 9, 41, 27, 4, 261, 18, 132, 262, 4, 10, 103, 22, 263, 42],
#  [1,
#   2,
#   21,
#   3,
#   5,
#   9,
#   41,
#   27,
#   4,
#   261,
#   18,
#   132,
#   262,
#   4,
#   10,
#   103,
#   22,
#   263,
#   42,
#   44],
#  [1,
#   2,
#   21,
#   3,
#   5,
#   9,
#   41,
#   27,
#   4,
#   261,
#   18,
#   132,
#   262,
#   4,
#   10,
#   103,
#   22,
#   263,
#   42,
#   44,
#   37],
#  [1,
#   2,
#   21,
#   3,
#   5,
#   9,
#   41,
#   27,
#   4,
#   261,
#   18,
#   132,
#   262,
#   4,
#   10,
#   103,
#   22,
#   263,
#   42,
#   44,
#   37,
#   15],
#  [1, 2],
#  [1, 2, 12],
#  [1, 2, 12, 3],
#  [1, 2, 12, 3, 5],
#  [1, 2, 12, 3, 5, 81],
#  [1, 2, 12, 3, 5, 81, 264],
#  [1, 2, 12, 3, 5, 81, 264, 6],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265, 73],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265, 73, 87],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265, 73, 87, 109],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265, 73, 87, 109, 24],
#  [1, 2, 12, 3, 5, 81, 264, 6, 112, 6, 17, 57, 122, 265, 73, 87, 109, 24, 266],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   81,
#   264,
#   6,
#   112,
#   6,
#   17,
#   57,
#   122,
#   265,
#   73,
#   87,
#   109,
#   24,
#   266,
#   7],
#  [13, 12],
#  [13, 12, 26],
#  [13, 12, 26, 14],
#  [13, 12, 26, 14, 20],
#  [13, 12, 26, 14, 20, 4],
#  [13, 12, 26, 14, 20, 4, 10],
#  [13, 12, 26, 14, 20, 4, 10, 267],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50, 133],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50, 133, 4],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50, 133, 4, 10],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50, 133, 4, 10, 9],
#  [13, 12, 26, 14, 20, 4, 10, 267, 268, 5, 49, 52, 4, 50, 133, 4, 10, 9, 269],
#  [13,
#   12,
#   26,
#   14,
#   20,
#   4,
#   10,
#   267,
#   268,
#   5,
#   49,
#   52,
#   4,
#   50,
#   133,
#   4,
#   10,
#   9,
#   269,
#   32],
#  [13,
#   12,
#   26,
#   14,
#   20,
#   4,
#   10,
#   267,
#   268,
#   5,
#   49,
#   52,
#   4,
#   50,
#   133,
#   4,
#   10,
#   9,
#   269,
#   32,
#   42],
#  [13,
#   12,
#   26,
#   14,
#   20,
#   4,
#   10,
#   267,
#   268,
#   5,
#   49,
#   52,
#   4,
#   50,
#   133,
#   4,
#   10,
#   9,
#   269,
#   32,
#   42,
#   15],
#  [1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 3],
#  [1, 2, 8, 3, 5],
#  [1, 2, 8, 3, 5, 46],
#  [1, 2, 8, 3, 5, 46, 270],
#  [1, 2, 8, 3, 5, 46, 270, 13],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125, 22],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125, 22, 32],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125, 22, 32, 24],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125, 22, 32, 24, 126],
#  [1, 2, 8, 3, 5, 46, 270, 13, 125, 22, 32, 24, 126, 7],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 271],
#  [1, 2, 21, 271, 18],
#  [1, 2, 21, 271, 18, 128],
#  [1, 2, 21, 271, 18, 128, 43],
#  [1, 2, 21, 271, 18, 128, 43, 272],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76, 273],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76, 273, 19],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76, 273, 19, 274],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76, 273, 19, 274, 275],
#  [1, 2, 21, 271, 18, 128, 43, 272, 17, 76, 273, 19, 274, 275, 276],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 3],
#  [1, 2, 23, 3, 6],
#  [1, 2, 23, 3, 6, 35],
#  [1, 2, 23, 3, 6, 35, 16],
#  [1, 2, 23, 3, 6, 35, 16, 277],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56, 134],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56, 134, 91],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56, 134, 91, 24],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56, 134, 91, 24, 37],
#  [1, 2, 23, 3, 6, 35, 16, 277, 38, 10, 17, 56, 134, 91, 24, 37, 15],
#  [1, 2],
#  [1, 2, 12],
#  [1, 2, 12, 3],
#  [1, 2, 12, 3, 4],
#  [1, 2, 12, 3, 4, 278],
#  [1, 2, 12, 3, 4, 278, 16],
#  [1, 2, 12, 3, 4, 278, 16, 27],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47, 16],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47, 16, 26],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47, 16, 26, 45],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47, 16, 26, 45, 19],
#  [1, 2, 12, 3, 4, 278, 16, 27, 5, 17, 279, 280, 61, 47, 16, 26, 45, 19, 281],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84,
#   43],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84,
#   43,
#   110],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84,
#   43,
#   110,
#   282],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84,
#   43,
#   110,
#   282,
#   116],
#  [1,
#   2,
#   12,
#   3,
#   4,
#   278,
#   16,
#   27,
#   5,
#   17,
#   279,
#   280,
#   61,
#   47,
#   16,
#   26,
#   45,
#   19,
#   281,
#   84,
#   43,
#   110,
#   282,
#   116,
#   15],
#  [13, 8],
#  [13, 8, 283],
#  [13, 8, 283, 75],
#  [13, 8, 283, 75, 18],
#  [13, 8, 283, 75, 18, 284],
#  [13, 8, 283, 75, 18, 284, 285],
#  [13, 8, 283, 75, 18, 284, 285, 286],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36, 6],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36, 6, 35],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36, 6, 35, 135],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36, 6, 35, 135, 43],
#  [13, 8, 283, 75, 18, 284, 285, 286, 33, 85, 20, 29, 36, 6, 35, 135, 43, 37],
#  [13,
#   8,
#   283,
#   75,
#   18,
#   284,
#   285,
#   286,
#   33,
#   85,
#   20,
#   29,
#   36,
#   6,
#   35,
#   135,
#   43,
#   37,
#   15],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 3],
#  [1, 2, 21, 3, 5],
#  [1, 2, 21, 3, 5, 46],
#  [1, 2, 21, 3, 5, 46, 136],
#  [1, 2, 21, 3, 5, 46, 136, 22],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38, 118],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38, 118, 6],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38, 118, 6, 288],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38, 118, 6, 288, 289],
#  [1, 2, 21, 3, 5, 46, 136, 22, 32, 11, 287, 33, 48, 38, 118, 6, 288, 289, 24],
#  [1,
#   2,
#   21,
#   3,
#   5,
#   46,
#   136,
#   22,
#   32,
#   11,
#   287,
#   33,
#   48,
#   38,
#   118,
#   6,
#   288,
#   289,
#   24,
#   129],
#  [1, 2],
#  [1, 2, 8],
#  [1, 2, 8, 31],
#  [1, 2, 8, 31, 87],
#  [1, 2, 8, 31, 87, 136],
#  [1, 2, 8, 31, 87, 136, 38],
#  [1, 2, 8, 31, 87, 136, 38, 10],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17, 290],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17, 290, 91],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17, 290, 91, 24],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17, 290, 91, 24, 40],
#  [1, 2, 8, 31, 87, 136, 38, 10, 17, 290, 91, 24, 40, 7],
#  [1, 2],
#  [1, 2, 12],
#  [1, 2, 12, 3],
#  [1, 2, 12, 3, 5],
#  [1, 2, 12, 3, 5, 9],
#  [1, 2, 12, 3, 5, 9, 97],
#  [1, 2, 12, 3, 5, 9, 97, 98],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77, 62],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77, 62, 71],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77, 62, 71, 72],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77, 62, 71, 72, 39],
#  [1, 2, 12, 3, 5, 9, 97, 98, 65, 22, 51, 90, 89, 63, 77, 62, 71, 72, 39, 25],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135,
#   52],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135,
#   52,
#   19],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135,
#   52,
#   19,
#   291],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135,
#   52,
#   19,
#   291,
#   292],
#  [1,
#   2,
#   12,
#   3,
#   5,
#   9,
#   97,
#   98,
#   65,
#   22,
#   51,
#   90,
#   89,
#   63,
#   77,
#   62,
#   71,
#   72,
#   39,
#   25,
#   35,
#   135,
#   52,
#   19,
#   291,
#   292,
#   15],
#  [13, 12],
#  [13, 12, 293],
#  [13, 12, 293, 294],
#  [13, 12, 293, 294, 88],
#  [13, 12, 293, 294, 88, 20],
#  [13, 12, 293, 294, 88, 20, 28],
#  [13, 12, 293, 294, 88, 20, 28, 55],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78, 29],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78, 29, 36],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78, 29, 36, 4],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78, 29, 36, 4, 296],
#  [13, 12, 293, 294, 88, 20, 28, 55, 35, 295, 33, 48, 78, 29, 36, 4, 296, 297],
#  [13,
#   12,
#   293,
#   294,
#   88,
#   20,
#   28,
#   55,
#   35,
#   295,
#   33,
#   48,
#   78,
#   29,
#   36,
#   4,
#   296,
#   297,
#   84],
#  [13,
#   12,
#   293,
#   294,
#   88,
#   20,
#   28,
#   55,
#   35,
#   295,
#   33,
#   48,
#   78,
#   29,
#   36,
#   4,
#   296,
#   297,
#   84,
#   102],
#  [1, 2],
#  [1, 2, 23],
#  [1, 2, 23, 3],
#  [1, 2, 23, 3, 6],
#  [1, 2, 23, 3, 6, 298],
#  [1, 2, 23, 3, 6, 298, 299],
#  [1, 2, 23, 3, 6, 298, 299, 25],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99, 63],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99, 63, 74],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99, 63, 74, 18],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99, 63, 74, 18, 62],
#  [1, 2, 23, 3, 6, 298, 299, 25, 300, 132, 301, 18, 99, 63, 74, 18, 62, 17],
#  [1,
#   2,
#   23,
#   3,
#   6,
#   298,
#   299,
#   25,
#   300,
#   132,
#   301,
#   18,
#   99,
#   63,
#   74,
#   18,
#   62,
#   17,
#   302],
#  [1,
#   2,
#   23,
#   3,
#   6,
#   298,
#   299,
#   25,
#   300,
#   132,
#   301,
#   18,
#   99,
#   63,
#   74,
#   18,
#   62,
#   17,
#   302,
#   303],
#  [1,
#   2,
#   23,
#   3,
#   6,
#   298,
#   299,
#   25,
#   300,
#   132,
#   301,
#   18,
#   99,
#   63,
#   74,
#   18,
#   62,
#   17,
#   302,
#   303,
#   7],
#  [1, 2],
#  [1, 2, 21],
#  [1, 2, 21, 304],
#  [68, 5],
#  [68, 5, 305],
#  [68, 5, 305, 130],
#  [68, 5, 305, 130, 306],
#  [68, 5, 305, 130, 306, 22],
#  [68, 5, 305, 130, 306, 22, 20],
#  [68, 5, 305, 130, 306, 22, 20, 4],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17, 307],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17, 307, 91],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17, 307, 91, 24],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17, 307, 91, 24, 40],
#  [68, 5, 305, 130, 306, 22, 20, 4, 10, 17, 307, 91, 24, 40, 7],
#  [13, 8],
#  [13, 8, 26],
#  [13, 8, 26, 14],
#  [13, 8, 26, 14, 20],
#  [13, 8, 26, 14, 20, 6],
#  [13, 8, 26, 14, 20, 6, 308],
#  [13, 8, 26, 14, 20, 6, 308, 4],
#  [13, 8, 26, 14, 20, 6, 308, 4, 10],
#  ...]

# %%
#checking token sentence
sentence_token = input_sequences[10]
sentence=[]
for token in sentence_token:
    sentence.append(list((tokenizer.word_index).keys()) [list((tokenizer.word_index).values()).index(token)])
print(sentence)
# Out:
# ['طالب', 'علم', '1', 'کیا', 'تم', 'نے', 'یونیورسٹی', 'آف', 'سندھ', 'کے', 'نئے', 'پروگرامز']

# %%
#padding
#maximum sentence length'
max_sequence_len = max([len(seq) for  seq in input_sequences])
#input sequences
input_sequences= np.array(pad_sequences(input_sequences,maxlen=max_sequence_len,padding='pre'))

# %%
input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   1,   2],
#        [  0,   0,   0, ...,   1,   2,   8],
#        [  0,   0,   0, ...,   2,   8,  11],
#        ...,
#        [  0,   0,   0, ...,  10,  17,  56],
#        [  0,   0,   0, ...,  17,  56, 134],
#        [  0,   0,   0, ...,  56, 134,   7]])

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
X.shape
# Out:
# (1052, 26)

# %%
y.shape
# Out:
# (1052,)

# %%
y=np.array(tf.keras.utils.to_categorical(y,num_classes=total_words))

# %%
#create mode;
model=Sequential()
model.add(Embedding(total_words,100,input_length=max_sequence_len-1))
model.add(LSTM(150))
model.add(Dense(total_words,activation='softmax'))

from tensorflow.keras import backend as K
K.clear_session()
# Out:
# c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# WARNING:tensorflow:From c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
#compile the model
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#fit the model
model.fit(X,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0427 - loss: 5.5929
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0544 - loss: 4.9990
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1031 - loss: 4.6653
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1242 - loss: 4.5942
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1489 - loss: 4.3423
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1392 - loss: 4.3102
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1871 - loss: 4.0802
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1870 - loss: 4.0114
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2182 - loss: 3.8269
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2006 - loss: 3.7847
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2502 - loss: 3.4852
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2626 - loss: 3.3709
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2829 - loss: 3.1871
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2950 - loss: 3.1138
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3273 - loss: 2.9089
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3678 - loss: 2.7728
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3657 - loss: 2.6575
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3991 - loss: 2.5772
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4192 - loss: 2.3784
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4671 - loss: 2.2453
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5055 - loss: 2.1562
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5171 - loss: 2.0887
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5470 - loss: 1.9919
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5787 - loss: 1.8716
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5927 - loss: 1.7973
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6566 - loss: 1.6931
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6676 - loss: 1.5971
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7009 - loss: 1.4705
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7257 - loss: 1.4471
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7353 - loss: 1.3272
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7481 - loss: 1.2622
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7473 - loss: 1.1723
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7693 - loss: 1.1325
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7808 - loss: 1.0966
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7950 - loss: 0.9959
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7899 - loss: 0.9867
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8137 - loss: 0.9374
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8240 - loss: 0.8867
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8268 - loss: 0.8591
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8347 - loss: 0.7882
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8323 - loss: 0.7710
# Epoch 42/100
#  5/33 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8627 - loss: 0.6778
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 #fit the model
# ----> 2 model.fit(X,y,epochs=100,verbose=1)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#determining the text
import time
seed_text ="یونیورسٹی میں ہر سال نئے تعلیمی"
next_words = 20

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
    print(seed_text)
    time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے جا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے جا رہے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے جا رہے ہیں۔
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے جا رہے ہیں۔ رہے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# یونیورسٹی میں ہر سال نئے تعلیمی پروگرامز کے حوالے سے معلومات دینے کے لیے سیمینارز بھی منعقد کیے جا رہے ہیں۔ رہے ہیں۔
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 9
#       7 token_list = tokenizer.texts_to_sequences([seed_text])[0]
#       8 token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
# ----> 9 predicted = np.argmax(model.predict(token_list), axis=-1)
#      10 output_word = ""
#      11 for word, index in tokenizer.word_index.items():
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:448, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 @traceback_utils.filter_traceback
#     444 def predict(
#     445     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     446 ):
#     447     # Create an iterator that yields batches of input data.
# --> 448     epoch_iterator = TFEpochIterator(
#     449         x=x,
#     450         batch_size=batch_size,
#     451         steps_per_epoch=steps,
#     452         shuffle=False,
#     453         distribute_strategy=self.distribute_strategy,
#     454         steps_per_execution=self.steps_per_execution,
#     455     )
#     457     # Container that configures and calls callbacks.
#     458     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:666, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     664 super().__init__(*args, **kwargs)
#     665 self._distribute_strategy = distribute_strategy
# --> 666 dataset = self._get_iterator()
#     667 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     668     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     669         dataset
#     670     )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:675, in TFEpochIterator._get_iterator(self)
#     674 def _get_iterator(self):
# --> 675     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:140, in ArrayDataAdapter.get_tf_dataset(self)
#     133     return indices
#     135 # We prefetch a single element. Computing large permutations can take
#     136 # quite a while so we don't want to wait for prefetching over an epoch
#     137 # boundary to trigger the next permutation. On the other hand, too many
#     138 # simultaneous shuffles can contend on a hardware level and degrade all
#     139 # performance.
# --> 140 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     142 def slice_batch_indices(indices):
#     143     """Convert a Tensor of indices into a dataset of batched indices.
#     144
#     145     This step can be accomplished in several ways. The most natural is
#    (...)
#     157         A Dataset of batched indices.
#     158     """
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# -> 2341 return map_op._map_v2(
#    2342     self,
#    2343     map_func,
#    2344     num_parallel_calls=num_parallel_calls,
#    2345     deterministic=deterministic,
#    2346     synchronous=synchronous,
#    2347     use_unbounded_threadpool=use_unbounded_threadpool,
#    2348     name=name,
#    2349 )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\data\ops\map_op.py:43, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#      38   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      39     warnings.warn(
#      40         "The `deterministic` argument has no effect unless the "
#      41         "`num_parallel_calls` argument is specified."
#      42     )
# ---> 43   return _MapDataset(
#      44       input_dataset,
#      45       map_func,
#      46       preserve_cardinality=True,
#      47       force_synchronous=False if synchronous is None else synchronous,
#      48       name=name,
#      49   )
#      50 else:
#      51   if synchronous:
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\data\ops\map_op.py:157, in _MapDataset.__init__(self, input_dataset, map_func, force_synchronous, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     155 self._use_inter_op_parallelism = use_inter_op_parallelism
#     156 self._preserve_cardinality = preserve_cardinality
# --> 157 self._map_func = structured_function.StructuredFunctionWrapper(
#     158     map_func,
#     159     self._transformation_name(),
#     160     dataset=input_dataset,
#     161     use_legacy_function=use_legacy_function)
#     162 self._force_synchronous = force_synchronous
#     163 self._name = name
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:340, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     331 output_type = trace_type.from_value(
#     332     traced_func_graph.structured_outputs, type_context
#     333 )
#     334 traced_func_type = function_type_lib.FunctionType(
#     335     function_type.parameters.values(),
#     336     traced_func_graph.function_captures.capture_types,
#     337     return_annotation=output_type,
#     338 )
# --> 340 concrete_function = concrete_function_lib.ConcreteFunction.from_func_graph(
#     341     traced_func_graph,
#     342     traced_func_type,
#     343     tracing_options.attributes,
#     344     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     345     # scope. This is not the default behavior since it gets used in some
#     346     # places (like Keras) where the FuncGraph lives longer than the
#     347     # ConcreteFunction.
#     348     shared_func_graph=False,
#     349 )
#     350 _set_arg_keywords(concrete_function)
#     351 transform.call_concrete_function_callbacks(concrete_function)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1075, in ConcreteFunction.from_func_graph(cls, graph, function_type, attrs, shared_func_graph)
#    1073 @classmethod
#    1074 def from_func_graph(cls, graph, function_type, attrs, shared_func_graph=True):
# -> 1075   atomic_fn = atomic_function.from_func_graph(
#    1076       _inference_name(graph.name), graph, attrs, function_type
#    1077   )
#    1078   return ConcreteFunction(atomic_fn, shared_func_graph=shared_func_graph)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:540, in from_func_graph(name, graph, attrs, function_type, overwrite)
#     538   output_names = []
#     539 with graph._c_graph.get() as c_graph:  # pylint: disable=protected-access
# --> 540   fn = pywrap_tf_session.TF_GraphToFunction_wrapper(
#     541       c_graph,
#     542       compat.as_str(name),
#     543       False,
#     544       [o._c_op for o in operations],  # pylint: disable=protected-access
#     545       [t._as_tf_output() for t in graph.inputs],  # pylint: disable=protected-access
#     546       [t._as_tf_output() for t in graph.outputs],  # pylint: disable=protected-access
#     547       output_names,
#     548       [o._c_op for o in graph.control_outputs],  # pylint: disable=protected-access
#     549       [],  # control_output_names
#     550       None,
#     551       compat.as_str(""),
#     552   )
#     554 attrs = attributes_lib.parse_func_attrs(attrs or {})
#     555 for attr_name, attr_value in attrs.items():
#
# KeyboardInterrupt:
